# %% [markdown]
# This is an intro / tutorial notebook for getting started with GTFS data.
#
# It is based on work that is shown on my dev blog [simplistic.me](http://simplistic.me/tag/gtfs.html). Posts there are not updated to current versions, mine or other packages'. Still, do check it out and feel free to comment or post an issue or pull request.
#
# This is only one basic workflow which I like. You can find many more examples for working with GTFS online. There are tools and packages in many languages.
#
# THE place to start is [awesome-transit](https://github.com/CUTR-at-USF/awesome-transit).
#
# TODO: Add more tools to this notebook - peartree, GTFSTK, UrbanAccess, Pandana

# %% [markdown]
# ## Installation
# TODO: Go to open-bus README (this needs to be there)
#
# 1. Install Anaconda3
# 1. Create a virtual environment (call it openbus or something indicative): `conda create -n openbus`
# 1. Clone [open-bus-explore](https://github.com/cjer/open-bus-explore) - `git clone https://github.com/cjer/open-bus-explore`
# 1. Install everything in [requirements.txt](https://github.com/cjer/open-bus-explore/blob/master/requirements.txt)
#     1. partridge, peartree and GTFSTK require `pip install`
#     1. the rest you should install using `conda install -c conda-forge <package_name>`
# 1. Run JupyterLab or Jupyter Notebook

# %% [markdown]
# ## Imports and config

# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import partridge as ptg
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
import datetime

from gtfs_utils import *

alt.renderers.enable('notebook')
alt.data_transformers.enable('json')

sns.set_style("white")
sns.set_context("talk")
sns.set_palette('Set2', 10)

# %% [markdown]
# ## Creating a `partridge` feed
# We have a util function for getting a `partridge` feed object by date.

# %%
LOCAL_GTFS_ZIP_PATH = 'data/gtfs_feeds/2019-02-03.zip' 
LOCAL_TARIFF_PATH = 'data/archive/2019-02-03/Tariff.zip'

# %%
feed = get_partridge_feed_by_date(LOCAL_GTFS_ZIP_PATH, datetime.date.today())
type(feed)
# Out:
# partridge.gtfs.feed

# %% [markdown]
# * *Another option would be to use `ptg.get_representative_feed()` which finds the busiest day of the gtfs file and returns a feed for that day. Not showing this here.*

# %% [markdown]
# The feed has in it all the (standard) files in the original GTFS zip, as [pandas](https://github.com/pandas-dev/pandas) DataFrames.

# %%
[x for x in dir(feed) if not x.startswith('_')]
# Out:
# ['agency',
#  'calendar',
#  'calendar_dates',
#  'config',
#  'fare_attributes',
#  'fare_rules',
#  'feed_info',
#  'frequencies',
#  'get',
#  'is_dir',
#  'path',
#  'read_file_chunks',
#  'routes',
#  'shapes',
#  'stop_times',
#  'stops',
#  'transfers',
#  'trips',
#  'view',
#  'zmap']

# %%
feed.stops.stop_code.astype(int).max()
# Out:
# 43078

# %%
feed.stops[feed.stops.stop_code.isin((feed.stops.groupby('stop_code').size()[feed.stops.groupby('stop_code').size()>1]).index)].sort_values('stop_code')
# Out:
#       stop_id stop_code                 stop_name  \
# 24068   37404     10030    ת. מרכזית אשדוד/רציפים
# 24071   37407     10030    ת. מרכזית אשדוד/רציפים
# 24070   37406     10030    ת. מרכזית אשדוד/רציפים
# 24069   37405     10030    ת. מרכזית אשדוד/רציפים
# 24001   37265     10030    ת. מרכזית אשדוד/רציפים
# 24072   37408     10030    ת. מרכזית אשדוד/רציפים
# 23785   36918     10313      ת. מרכזית ערד/רציפים
# 23784   36917     10313      ת. מרכזית ערד/רציפים
# 23770   36877     10313      ת. מרכזית ערד/רציפים
# 23632   36154     10313      ת. מרכזית ערד/רציפים
# 23768   36867     10313      ת. מרכזית ערד/רציפים
# 23638   36181     10466     ת. מרכזית אילת/רציפים
# 27837   42844     10466     ת. מרכזית אילת/רציפים
# 23715   36558     10466     ת. מרכזית אילת/רציפים
# 23664   36312     10466     ת. מרכזית אילת/רציפים
# 23666   36329     10466     ת. מרכזית אילת/רציפים
# 23639   36187     10466     ת. מרכזית אילת/רציפים
# 23804   36947     11001    ת. מרכזית אשדוד/רציפים
# 24220   37658     11001    ת. מרכזית אשדוד/רציפים
# 23723   36763     11001    ת. מרכזית אשדוד/רציפים
# 24221   37659     11001    ת. מרכזית אשדוד/רציפים
# 24140   37537     11001    ת. מרכזית אשדוד/רציפים
# 24218   37656     11001    ת. מרכזית אשדוד/רציפים
# 23720   36599     11001    ת. מרכזית אשדוד/רציפים
# 24219   37657     11001    ת. מרכזית אשדוד/רציפים
# 24222   37660     11001    ת. מרכזית אשדוד/רציפים
# 24967   38961     11001    ת. מרכזית אשדוד/רציפים
# 27701   42623     12000  ת. רכבת מלאכי-יואב/איסוף
# 27495   42242     12000  ת. רכבת מלאכי-יואב/איסוף
# 27496   42243     12001  ת. רכבת מלאכי-יואב/הורדה
# ...       ...       ...                       ...
# 23672   36361     55637    ת. מרכזית עפולה/רציפים
# 24251   37704     55815   ת. מרכזית כרמיאל/רציפים
# 24250   37703     55815   ת. מרכזית כרמיאל/רציפים
# 24150   37549     55815   ת. מרכזית כרמיאל/רציפים
# 27536   42316     55816            מסוף מגדל העמק
# 27662   42541     55816            מסוף מגדל העמק
# 24304   37788     57001    ת. מרכזית טבריה/רציפים
# 23645   36224     57001    ת. מרכזית טבריה/רציפים
# 23641   36199     57001    ת. מרכזית טבריה/רציפים
# 24305   37789     57001    ת. מרכזית טבריה/רציפים
# 23724   36767     57001    ת. מרכזית טבריה/רציפים
# 26342   40731     57001    ת. מרכזית טבריה/רציפים
# 23710   36537     57001    ת. מרכזית טבריה/רציפים
# 26345   40734     57001    ת. מרכזית טבריה/רציפים
# 26344   40733     57001    ת. מרכזית טבריה/רציפים
# 26343   40732     57001    ת. מרכזית טבריה/רציפים
# 24217   37655     57001    ת. מרכזית טבריה/רציפים
# 27541   42321     57453              מסוף בית שאן
# 27592   42454     57453              מסוף בית שאן
# 27547   42399     57453              מסוף בית שאן
# 24151   37550     58002      ת. מרכזית צפת/רציפים
# 24556   38379     58002      ת. מרכזית צפת/רציפים
# 24174   37599     58002      ת. מרכזית צפת/רציפים
# 24784   38740     58002      ת. מרכזית צפת/רציפים
# 24307   37795     58002      ת. מרכזית צפת/רציפים
# 27544   42352     59903   מסוף חצור הגלילית/הורדה
# 27548   42400     59903   מסוף חצור הגלילית/הורדה
# 27565   42424     59903   מסוף חצור הגלילית/הורדה
# 27457   42157     61316     מסוף שער בנימין/איסוף
# 27456   42156     61316     מסוף שער בנימין/איסוף
#
#                                                stop_desc   stop_lat  \
# 24068       רחוב:קניון הסיטי  עיר: אשדוד רציף: 1   קומה:  31.790888
# 24071       רחוב:קניון הסיטי  עיר: אשדוד רציף: 5   קומה:  31.790888
# 24070       רחוב:קניון הסיטי  עיר: אשדוד רציף: 4   קומה:  31.790888
# 24069       רחוב:קניון הסיטי  עיר: אשדוד רציף: 3   קומה:  31.790888
# 24001       רחוב:קניון הסיטי  עיר: אשדוד רציף: 2   קומה:  31.790888
# 24072       רחוב:קניון הסיטי  עיר: אשדוד רציף: 6   קומה:  31.790888
# 23785                    רחוב:  עיר: ערד רציף: 5   קומה:  31.255802
# 23784                    רחוב:  עיר: ערד רציף: 2   קומה:  31.255802
# 23770                    רחוב:  עיר: ערד רציף: 1   קומה:  31.255802
# 23632                    רחוב:  עיר: ערד רציף: 4   קומה:  31.255802
# 23768                    רחוב:  עיר: ערד רציף: 3   קומה:  31.255802
# 23638                   רחוב:  עיר: אילת רציף: 7   קומה:  29.556565
# 27837                   רחוב:  עיר: אילת רציף: 4   קומה:  29.556565
# 23715                   רחוב:  עיר: אילת רציף: 2   קומה:  29.556565
# 23664                   רחוב:  עיר: אילת רציף: 6   קומה:  29.556565
# 23666                   רחוב:  עיר: אילת רציף: 1   קומה:  29.556565
# 23639                   רחוב:  עיר: אילת רציף: 5   קומה:  29.556565
# 23804                  רחוב:  עיר: אשדוד רציף: 1   קומה:  31.790926
# 24220                  רחוב:  עיר: אשדוד רציף: 6   קומה:  31.790926
# 23723                  רחוב:  עיר: אשדוד רציף: 3   קומה:  31.790926
# 24221                  רחוב:  עיר: אשדוד רציף: 7   קומה:  31.790926
# 24140                  רחוב:  עיר: אשדוד רציף: 9   קומה:  31.790926
# 24218                  רחוב:  עיר: אשדוד רציף: 4   קומה:  31.790926
# 23720                  רחוב:  עיר: אשדוד רציף: 2   קומה:  31.790926
# 24219                  רחוב:  עיר: אשדוד רציף: 5   קומה:  31.790926
# 24222                  רחוב:  עיר: אשדוד רציף: 8   קומה:  31.790926
# 24967                  רחוב:  עיר: אשדוד רציף: 10  קומה:  31.790926
# 27701                   רחוב:  עיר: יואב רציף: 1   קומה:  31.746571
# 27495                     רחוב:  עיר: יואב רציף:   קומה:  31.746571
# 27496                     רחוב:  עיר: יואב רציף:   קומה:  31.746204
# ...                                                  ...        ...
# 23672                  רחוב:  עיר: עפולה רציף: 5   קומה:  32.607821
# 24251                 רחוב:  עיר: כרמיאל רציף: 3   קומה:  32.922952
# 24250                 רחוב:  עיר: כרמיאל רציף: 2   קומה:  32.922952
# 24150                 רחוב:  עיר: כרמיאל רציף: 1   קומה:  32.922952
# 27536                רחוב:  עיר: מגדל העמק רציף:   קומה:  32.679317
# 27662              רחוב:  עיר: מגדל העמק רציף: 1   קומה:  32.679317
# 24304               רחוב:411  עיר: טבריה רציף: 6   קומה:  32.787514
# 23645               רחוב:411  עיר: טבריה רציף: 3   קומה:  32.787514
# 23641               רחוב:411  עיר: טבריה רציף: 8   קומה:  32.787514
# 24305               רחוב:411  עיר: טבריה רציף: 7   קומה:  32.787514
# 23724               רחוב:411  עיר: טבריה רציף: 10  קומה:  32.787514
# 26342               רחוב:411  עיר: טבריה רציף: 11  קומה:  32.787514
# 23710               רחוב:411  עיר: טבריה רציף: 9   קומה:  32.787514
# 26345               רחוב:411  עיר: טבריה רציף: 14  קומה:  32.787514
# 26344               רחוב:411  עיר: טבריה רציף: 13  קומה:  32.787514
# 26343               רחוב:411  עיר: טבריה רציף: 12  קומה:  32.787514
# 24217               רחוב:411  עיר: טבריה רציף: 5   קומה:  32.787514
# 27541   רחוב:שדרות מנחם בגין  עיר: בית שאן רציף:   קומה:  32.498160
# 27592  רחוב:שדרות מנחם בגין  עיר: בית שאן רציף: 5   ק...  32.498160
# 27547  רחוב:שדרות מנחם בגין  עיר: בית שאן רציף: 1   ק...  32.498160
# 24151                    רחוב:  עיר: צפת רציף: 1   קומה:  32.969703
# 24556                    רחוב:  עיר: צפת רציף: 3   קומה:  32.969703
# 24174                    רחוב:  עיר: צפת רציף: 2   קומה:  32.969703
# 24784                    רחוב:  עיר: צפת רציף: 4   קומה:  32.969703
# 24307                    רחוב:  עיר: צפת רציף: 5   קומה:  32.969703
# 27544             רחוב:  עיר: חצור הגלילית רציף:   קומה:  32.980861
# 27548           רחוב:  עיר: חצור הגלילית רציף: 1   קומה:  32.980861
# 27565             רחוב:  עיר: חצור הגלילית רציף:   קומה:  32.980861
# 27457             רחוב:  עיר: מטה בנימין רציף: 2   קומה:  31.864886
# 27456             רחוב:  עיר: מטה בנימין רציף: 1   קומה:  31.864886
#
#         stop_lon  location_type parent_station zone_id
# 24068  34.639905              0          11947      70
# 24071  34.639905              0          11947      70
# 24070  34.639905              0          11947      70
# 24069  34.639905              0          11947      70
# 24001  34.639905              0          11947      70
# 24072  34.639905              0          11947      70
# 23785  35.211836              0          12209    2560
# 23784  35.211836              0          12209    2560
# 23770  35.211836              0          12209    2560
# 23632  35.211836              0          12209    2560
# 23768  35.211836              0          12209    2560
# 23638  34.952682              0          12362    2600
# 27837  34.952682              0          12362    2600
# 23715  34.952682              0          12362    2600
# 23664  34.952682              0          12362    2600
# 23666  34.952682              0          12362    2600
# 23639  34.952682              0          12362    2600
# 23804  34.639056              0          25539      70
# 24220  34.639056              0          25539      70
# 23723  34.639056              0          25539      70
# 24221  34.639056              0          25539      70
# 24140  34.639056              0          25539      70
# 24218  34.639056              0          25539      70
# 23720  34.639056              0          25539      70
# 24219  34.639056              0          25539      70
# 24222  34.639056              0          25539      70
# 24967  34.639056              0          25539      70
# 27701  34.821871              0          42174    1913
# 27495  34.821871              0          42174    1913
# 27496  34.821985              0          42173    1913
# ...          ...            ...            ...     ...
# 23672  35.292233              0           4967    7700
# 24251  35.299805              0          37411    1139
# 24250  35.299805              0          37411    1139
# 24150  35.299805              0          37411    1139
# 27536  35.239048              0          37410     874
# 27662  35.239048              0          37410     874
# 24304  35.536817              0           5216    6700
# 23645  35.536817              0           5216    6700
# 23641  35.536817              0           5216    6700
# 24305  35.536817              0           5216    6700
# 23724  35.536817              0           5216    6700
# 26342  35.536817              0           5216    6700
# 23710  35.536817              0           5216    6700
# 26345  35.536817              0           5216    6700
# 26344  35.536817              0           5216    6700
# 26343  35.536817              0           5216    6700
# 24217  35.536817              0           5216    6700
# 27541  35.505008              0           5561    9200
# 27592  35.505008              0           5561    9200
# 27547  35.505008              0           5561    9200
# 24151  35.497205              0           5615    8000
# 24556  35.497205              0           5615    8000
# 24174  35.497205              0           5615    8000
# 24784  35.497205              0           5615    8000
# 24307  35.497205              0           5615    8000
# 27544  35.556525              0           7197    2034
# 27548  35.556525              0           7197    2034
# 27565  35.556525              0           7197    2034
# 27457  35.261684              0          42149      73
# 27456  35.261684              0          42149      73
#
# [388 rows x 9 columns]

# %% [markdown]
# Figuring out geographical zones requires using another zip file on MoT's FTP, using `get_zones_df()`. Which returns a simple mapping `stop_code` -> (Hebrew) `zone_name` in a DataFrame as well.

# %%
zones = get_zones_df(LOCAL_TARIFF_PATH)
zones.head()
# Out:
#   stop_code     zone_name
# 0         1  אזור בית שמש
# 1         2  אזור בית שמש
# 2         3   הרי ירושלים
# 3         4  אזור בית שמש
# 4         5  אזור בית שמש

# %%
feed.routes.shape
# Out:
# (6690, 7)

# %%
feed.routes.route_color.value_counts()
# Out:
# FF9933    1370
# 33CC33     228
# 9933FF       9
# Name: route_color, dtype: int64

# %% [markdown]
# ## Tidy DataFrame
# A (monstrous) merged DataFrame for fancy analysis can be got using `get_tidy_feed_df()`, whom you pass a partridge feed and extra dataframes you want to merge to it (only `zones` is used here).
#
# This takes a few minutes (MoT's GTFS is big)

# %%
f = get_tidy_feed_df(feed, [zones])

# %% [markdown]
# and what you get is this:

# %%
f.head()
# Out:
#            trip_id departure_time arrival_time stop_id  stop_sequence  \
# 0  10096398_020219       21:00:00     21:00:00   34657              1
# 1  10096398_020219       21:00:40     21:00:40   35317              2
# 2  10096398_020219       21:01:56     21:01:56   34436              3
# 3  10096398_020219       21:04:18     21:04:18   34444              4
# 4  10096398_020219       21:14:43     21:14:43   35506              5
#
#                  stop_name   stop_lat   stop_lon stop_code route_id  \
# 0        קניון קרני שומרון  32.174395  35.091190     63436     9735
# 1  שדרות רחבעם/קרני שומרון  32.175203  35.093854     65268     9735
# 2      קוממיות/שדרות רחבעם  32.175484  35.099323     63200     9735
# 3                נווה מנחם  32.179561  35.107716     63213     9735
# 4           יקיר בסיס צבאי  32.145644  35.116951     65290     9735
#
#   direction_id route_short_name  \
# 0            1               70
# 1            1               70
# 2            1               70
# 3            1               70
# 4            1               70
#
#                                      route_long_name agency_id agency_name  \
# 0  קניון קרני שומרון-קרני שומרון<->אוניברסיטת ארי...        25      אפיקים
# 1  קניון קרני שומרון-קרני שומרון<->אוניברסיטת ארי...        25      אפיקים
# 2  קניון קרני שומרון-קרני שומרון<->אוניברסיטת ארי...        25      אפיקים
# 3  קניון קרני שומרון-קרני שומרון<->אוניברסיטת ארי...        25      אפיקים
# 4  קניון קרני שומרון-קרני שומרון<->אוניברסיטת ארי...        25      אפיקים
#
#   zone_name
# 0   השומרון
# 1   השומרון
# 2   השומרון
# 3   השומרון
# 4   השומרון

# %% [markdown]
# In the future I intend to make this more customizable (field selection, transformations and more).

# %%
f.shape
# Out:
# (3388973, 16)

# %%
f.dtypes
# Out:
# trip_id                      object
# departure_time      timedelta64[ns]
# arrival_time        timedelta64[ns]
# stop_id                      object
# stop_sequence                 int64
# stop_name                    object
# stop_lat                    float64
# stop_lon                    float64
# stop_code                    object
# route_id                   category
# direction_id               category
# route_short_name           category
# route_long_name              object
# agency_id                  category
# agency_name                category
# zone_name                  category
# dtype: object

# %%
feed.stop_times.shape
# Out:
# (3388973, 8)

# %%
feed.routes[feed.routes.route_id=='10001']
# Out:
#      route_id agency_id route_short_name  \
# 2923    10001        14               91
#
#                                        route_long_name route_desc  route_type  \
# 2923  האר''י/ישראל ב''ק-צפת<->שפרינצק/קרן היסוד-צפת-2#  27091-2-#           3
#
#      route_color
# 2923      FF9933

# %%
school_routes = feed.routes[feed.routes.route_color=='FF9933'].route_id.values
school_routes
# Out:
# array(['270', '396', '397', ..., '25264', '25270', '25271'], dtype=object)

# %%
school_trips = f[f.route_id.isin(school_routes)].groupby('route_id').trip_id.nunique()
school_trips = school_trips[school_trips>0]

# %%
school_trips.mean()
# Out:
# 1.5605839416058394

# %%
f.groupby('route_id').trip_id.nunique().mean()
# Out:
# 14.3

# %%
school_trips.sum()
# Out:
# 2138

# %%
f.trip_id.nunique()
# Out:
# 95667

# %% [markdown]
# So we truly have all the stop times for one whole day of trips.

# %%
morning_school_trips = f[(f.route_id.isin(school_routes)) & (f.departure_time>=pd.Timedelta('7 hours')) & (f.departure_time<=pd.Timedelta('9 hours'))].groupby('route_id').trip_id.nunique()
morning_school_trips = morning_school_trips[morning_school_trips>0]

# %%
morning_school_trips.sum()
# Out:
# 851

# %%
f[(f.departure_time>=pd.Timedelta('7 hours')) & (f.departure_time<=pd.Timedelta('9 hours'))].trip_id.nunique()
# Out:
# 18176

# %%
morn_school_by_zone = f[(f.route_id.isin(school_routes)) & (f.departure_time>=pd.Timedelta('7 hours')) & (f.departure_time<=pd.Timedelta('9 hours'))].groupby('zone_name').trip_id.nunique()
morn_total_by_zone = f[(f.departure_time>=pd.Timedelta('7 hours')) & (f.departure_time<=pd.Timedelta('9 hours'))].groupby('zone_name').trip_id.nunique()

morn_zone = pd.concat([morn_school_by_zone, morn_total_by_zone], axis=1, keys=['school', 'total'])
morn_zone['ratio'] = morn_zone.school / morn_zone.total
morn_zone.sort_values('ratio', ascending=False)
# Out:
#                            school  total     ratio
# zone_name
# גליל עליון ורמת הגולן          57    340  0.167647
# סובב כנרת ודרום רמת הגולן      34    317  0.107256
# יוקנעם- טבעון                  35    338  0.103550
# כרמיאל                         49    479  0.102296
# זכרון                          13    137  0.094891
# נהריה                          24    266  0.090226
# השומרון                         9    113  0.079646
# נצרת                           69    904  0.076327
# חבל מודיעין                    35    527  0.066414
# סובב חיפה                     116   1837  0.063146
# חריש ואדי ערה                  32    576  0.055556
# רחובות                         27    531  0.050847
# נתניה                          39    813  0.047970
# ערד דימונה                     10    221  0.045249
# אשקלון                         25    561  0.044563
# סובב ירושלים                  125   2916  0.042867
# עכו                            19    461  0.041215
# שרון                           46   1245  0.036948
# ראש העין שוהם                  24    716  0.033520
# גוש דן                         82   5660  0.014488
# אשדוד                           8    648  0.012346
# באר שבע                        10    828  0.012077
# עפולה                           3    363  0.008264
# עומר חורה                       1    124  0.008065
# אזור בית שמש                    3    375  0.008000
# הרי ירושלים                     3    529  0.005671
# קריית גת                        1    194  0.005155
# אזור חדרה                       0    250  0.000000
# רהט להבים                       0    230  0.000000
# אזור קריית ארבע                 0     32  0.000000
# בית שאן                         0     77  0.000000
# בנימין                          0     57  0.000000
# בקעת ים המלח                    0     12  0.000000
# נתיבות שדרות                    0    272  0.000000
# גוש עציון                       0     82  0.000000
# גוש שילה ובקעה                  0     20  0.000000
# ירוחם                           0     59  0.000000
# דרום הר חברון                   0     21  0.000000
# אופקים                          0    214  0.000000

# %%
morn_zone.shape
# Out:
# (39, 3)

# %%
morn_zone[morn_zone.ratio<0.01].shape
# Out:
# (17, 3)

# %%
morn_zone[morn_zone.ratio==0].shape
# Out:
# (12, 3)

# %% [markdown]
# וכדי לקבל סדר גודל. זה מתוך סה"כ 6690 חלופות ברחבי הארץ. קצת יותר מעשרים אחוז.
#
# מן הסתם, אם מסתכלים על סך הנסיעות, זה הרבה פחות - קצת יותר מ-2%. אבל אם מסתכלים על נסיעות הבוקר בלבד (7 עד 9) הסעות תלמידים הן כמעט 5% מסך הנסיעות ברחבי הארץ.
#
# בחתך אשכולות גם עולים דברים מעניינים. השיא הוא של גליל עליון ורמת הגולן - 17% מנסיעות הבוקר שם הן נסיעות תלמידים. במטרופולינים גוש דן, ירושלים וחיפה זה 1%, 4% ו-6% בהתאמה. יש גם לא מעט אשכולות ללא הסעות תלמידים בכלל. 17 מתוך 39 עם פחות מ-1%, 12 מתוכם ללא נסיעות תלמידים בכלל. הגדולים בינהם הם חדרה, רהט-להבים, נתיבות-שדרות ואופקים.

# %%
feed.stops.head()
# Out:
#   stop_id stop_code             stop_name  \
# 0       1     38831  בי''ס בר לב/בן יהודה
# 1       2     38832        הרצל/צומת בילו
# 2       3     38833        הנחשול/הדייגים
# 3       4     38834        פריד/ששת הימים
# 4       6     38836   ת. מרכזית לוד/הורדה
#
#                                        stop_desc   stop_lat   stop_lon  \
# 0    רחוב:בן יהודה 76 עיר: כפר סבא רציף:   קומה:  32.183939  34.917812
# 1       רחוב:הרצל  עיר: קרית עקרון רציף:   קומה:  31.870034  34.819541
# 2  רחוב:הנחשול 30 עיר: ראשון לציון רציף:   קומה:  31.984553  34.782828
# 3      רחוב:משה פריד 9 עיר: רחובות רציף:   קומה:  31.888550  34.790904
# 4                  רחוב:  עיר: לוד רציף:   קומה:  31.956576  34.898125
#
#    location_type parent_station zone_id
# 0              0            NaN    6900
# 1              0            NaN     469
# 2              0            NaN    8300
# 3              0            NaN    8400
# 4              0            NaN    7000

# %%
fields = { 'street': 'רחוב', 
           'city': 'עיר', 
           'platform': 'רציף', 
           'floor': 'קומה' }

prefix='stop_desc_'

STOP_DESC_RE = ''
for n, fld in fields.items():
    STOP_DESC_RE += fld+f':(?P<{prefix+n}>.*)'
    
STOP_DESC_RE
# Out:
# 'רחוב:(?P<stop_desc_street>.*)עיר:(?P<stop_desc_city>.*)רציף:(?P<stop_desc_platform>.*)קומה:(?P<stop_desc_floor>.*)'

# %%
#STOP_DESC_RE = 'רחוב:(.*)עיר:(.*)רציף:(.*)קומה:(.*)'

# %%
feed.stops.stop_desc.iat[0]
# Out:
# 'רחוב:בן יהודה 76 עיר: כפר סבא רציף:   קומה:'

# %%
sd = feed.stops.stop_desc.str.extract(STOP_DESC_RE).apply(lambda x: x.str.strip())

sd.head()
# Out:
#   stop_desc_street stop_desc_city stop_desc_platform stop_desc_floor
# 0      בן יהודה 76        כפר סבא
# 1             הרצל     קרית עקרון
# 2        הנחשול 30    ראשון לציון
# 3       משה פריד 9         רחובות
# 4                             לוד

# %%
pd.concat([feed.stops.stop_desc, sd], axis=1)
# Out:
#                                                stop_desc stop_desc_street  \
# 0            רחוב:בן יהודה 76 עיר: כפר סבא רציף:   קומה:      בן יהודה 76
# 1               רחוב:הרצל  עיר: קרית עקרון רציף:   קומה:             הרצל
# 2          רחוב:הנחשול 30 עיר: ראשון לציון רציף:   קומה:        הנחשול 30
# 3              רחוב:משה פריד 9 עיר: רחובות רציף:   קומה:       משה פריד 9
# 4                          רחוב:  עיר: לוד רציף:   קומה:
# 5              רחוב:חנה אברך 9 עיר: רחובות רציף:   קומה:       חנה אברך 9
# 6             רחוב:הרצל 20 עיר: קרית עקרון רציף:   קומה:          הרצל 20
# 7             רחוב:הבנים 4 עיר: קרית עקרון רציף:   קומה:          הבנים 4
# 8           רחוב:וייצמן 11 עיר: קרית עקרון רציף:   קומה:        וייצמן 11
# 9           רחוב:האירוס 16 עיר: קרית עקרון רציף:   קומה:        האירוס 16
# 10            רחוב:הכלנית  עיר: קרית עקרון רציף:   קומה:           הכלנית
# 11         רחוב:אלי כהן 62 עיר: קרית עקרון רציף:   קומה:       אלי כהן 62
# 12            רחוב:שבזי 40 עיר: קרית עקרון רציף:   קומה:          שבזי 40
# 13            רחוב:שבזי 31 עיר: קרית עקרון רציף:   קומה:          שבזי 31
# 14        רחוב:חיים ברלב  עיר: ראשון לציון רציף:   קומה:        חיים ברלב
# 15                     רחוב:  עיר: צור משה רציף:   קומה:
# 16                     רחוב:  עיר: צור משה רציף:   קומה:
# 17           רחוב:חיים הולצמן  עיר: רחובות רציף:   קומה:      חיים הולצמן
# 18                    רחוב:  עיר: באר יעקב רציף:   קומה:
# 19             רחוב:הרצל 4 עיר: קרית עקרון רציף:   קומה:           הרצל 4
# 20                רחוב:הרותם 3 עיר: רחובות רציף:   קומה:          הרותם 3
# 21                רחוב:הערבה  עיר: צור משה רציף:   קומה:            הערבה
# 22               רחוב:מבוא הגפן  עיר: ינוב רציף:   קומה:        מבוא הגפן
# 23               רחוב:מבוא הגפן  עיר: ינוב רציף:   קומה:        מבוא הגפן
# 24                רחוב:ההרחבה  עיר: גאולים רציף:   קומה:           ההרחבה
# 25                רחוב:ההרחבה  עיר: גאולים רציף:   קומה:           ההרחבה
# 26                רחוב:ההרחבה  עיר: גאולים רציף:   קומה:           ההרחבה
# 27     רחוב:שדרות העליה  עיר: נמל תעופה בן גוריון רצי...      שדרות העליה
# 28      רחוב:כנף  עיר: נמל תעופה בן גוריון רציף:   קומה:              כנף
# 29              רחוב:החבורה 24 עיר: רחובות רציף:   קומה:        החבורה 24
# ...                                                  ...              ...
# 27849            רחוב:  עיר: תל אביב יפו רציף: 11  קומה:
# 27851            רחוב:  עיר: תל אביב יפו רציף: 10  קומה:
# 27852            רחוב:  עיר: תל אביב יפו רציף: 13  קומה:
# 27853            רחוב:  עיר: תל אביב יפו רציף: 8   קומה:
# 27854            רחוב:  עיר: תל אביב יפו רציף: 9   קומה:
# 27855          רחוב:1285  עיר: תל אביב יפו רציף:   קומה:             1285
# 27856            רחוב:  עיר: תל אביב יפו רציף: 7   קומה:
# 27857            רחוב:  עיר: תל אביב יפו רציף: 14  קומה:
# 27858            רחוב:  עיר: תל אביב יפו רציף: 15  קומה:
# 27859            רחוב:  עיר: תל אביב יפו רציף: 2   קומה:
# 27860            רחוב:  עיר: תל אביב יפו רציף: 3   קומה:
# 27861            רחוב:  עיר: תל אביב יפו רציף: 4   קומה:
# 27862            רחוב:  עיר: תל אביב יפו רציף: 5   קומה:
# 27863                 רחוב:742  עיר: שפרעם רציף:   קומה:              742
# 27864    רחוב:אבשלום גיסין  עיר: פתח תקווה רציף:   קומה:     אבשלום גיסין
# 27865        רחוב:אבי אורן  עיר: פתח תקווה רציף:   קומה:         אבי אורן
# 27866          רחוב:הסיבים  עיר: פתח תקווה רציף:   קומה:           הסיבים
# 27867          רחוב:עין עבדת 2 עיר: אשקלון רציף:   קומה:       עין עבדת 2
# 27872                רחוב:  עיר: חבל אילות רציף:   קומה:
# 27873              רחוב:8721  עיר: מטה אשר רציף:   קומה:             8721
# 27874                  רחוב:תמר  עיר: חריש רציף:   קומה:              תמר
# 27875                  רחוב:תמר  עיר: חריש רציף:   קומה:              תמר
# 27876                רחוב:ברלב  עיר: שדרות רציף:   קומה:             ברלב
# 27877             רחוב:60  עיר: מטה בנימין רציף:   קומה:               60
# 27878             רחוב:60  עיר: מטה בנימין רציף:   קומה:               60
# 27879              רחוב:  עיר: חבל אילות רציף: 1   קומה:
# 27880              רחוב:  עיר: חבל אילות רציף: 2   קומה:
# 27881                    רחוב:  עיר: לוד רציף: 1   קומה:
# 27882                    רחוב:  עיר: לוד רציף: 1   קומה:
# 27883          רחוב:הרב מיימון  עיר: בת ים רציף:   קומה:       הרב מיימון
#
#             stop_desc_city stop_desc_platform stop_desc_floor
# 0                  כפר סבא
# 1               קרית עקרון
# 2              ראשון לציון
# 3                   רחובות
# 4                      לוד
# 5                   רחובות
# 6               קרית עקרון
# 7               קרית עקרון
# 8               קרית עקרון
# 9               קרית עקרון
# 10              קרית עקרון
# 11              קרית עקרון
# 12              קרית עקרון
# 13              קרית עקרון
# 14             ראשון לציון
# 15                 צור משה
# 16                 צור משה
# 17                  רחובות
# 18                באר יעקב
# 19              קרית עקרון
# 20                  רחובות
# 21                 צור משה
# 22                    ינוב
# 23                    ינוב
# 24                  גאולים
# 25                  גאולים
# 26                  גאולים
# 27     נמל תעופה בן גוריון
# 28     נמל תעופה בן גוריון
# 29                  רחובות
# ...                    ...                ...             ...
# 27849          תל אביב יפו                 11
# 27851          תל אביב יפו                 10
# 27852          תל אביב יפו                 13
# 27853          תל אביב יפו                  8
# 27854          תל אביב יפו                  9
# 27855          תל אביב יפו
# 27856          תל אביב יפו                  7
# 27857          תל אביב יפו                 14
# 27858          תל אביב יפו                 15
# 27859          תל אביב יפו                  2
# 27860          תל אביב יפו                  3
# 27861          תל אביב יפו                  4
# 27862          תל אביב יפו                  5
# 27863                שפרעם
# 27864            פתח תקווה
# 27865            פתח תקווה
# 27866            פתח תקווה
# 27867               אשקלון
# 27872            חבל אילות
# 27873              מטה אשר
# 27874                 חריש
# 27875                 חריש
# 27876                שדרות
# 27877           מטה בנימין
# 27878           מטה בנימין
# 27879            חבל אילות                  1
# 27880            חבל אילות                  2
# 27881                  לוד                  1
# 27882                  לוד                  1
# 27883                בת ים
#
# [27672 rows x 5 columns]
